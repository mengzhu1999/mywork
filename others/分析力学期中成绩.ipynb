# %% [markdown]
# ### 分析力学期中成绩

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
import mplhep as hep
hep.style.use('ATLAS')
from tqdm import tqdm

# %%
# data =  np.loadtxt("/home/mengzhu/下载/分析力学期中成绩-工作表2.dat")

# %%
data = [100,
99,
98,
95,
95,
94.5,
94.5,
94,
92,
90,
88.5,
87.5,
87.5,
86.5,
86,
85.5,
85,
84.5,
84.5,
84.5,
84.5,
83.5,
83.5,
83.5,
82.5,
81,
80,
79.5,
79,
79,
78.5,
78.5,
78.5,
78,
77.5,
77,
76,
76,
75.5,
75.5,
75,
70,
68.5,
66.5,
63,
61.5,
60,
59,
58.5,
58,
51.5,
50,
50,
47,
45.5,
45,
45,
43,
42,
41.5,
37.5,
34,
31.5,
31,
23.5,
13]

# %%
n,bins,pacths = plt.hist(data,bins=10,range=(0,100))
for i in range(len(n)):
        plt.text(bins[i]+(bins[1]-bins[0])/2, n[i]*1.01, int(n[i]), ha='center', va= 'bottom')
sc = range(0,101,10)
plt.xticks(sc)
plt.xlabel('Score')
plt.ylabel('Frequency')


# # plt.legend()
# Out:
# Text(0, 1, 'Frequency')
